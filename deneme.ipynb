# %%
import pandas as pd
import numpy as np
import matplotlib
import seaborn as sns

# %%
sample = pd.read_csv("/Users/eyupburakatahanli/Desktop/tubitak_2209_projem/dataset_combined/dataset_combined/Ümraniye1.csv")

# %%
help.read_datasets()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 help.read_datasets()
#
# AttributeError: module 'helper' has no attribute 'read_datasets'

# %%
sample['ReadTime'] = pd.to_datetime(sample['ReadTime'], format='%Y-%m-%dT%H:%M:%S')

# %%
fig, ax = plt.subplots(figsize=(10, 6))

# Çizgi grafiği ekle
sns.lineplot(data=sample, x=sample.index, y='AQIINDEX_AQI', ax=ax)

# Başlık ve eksen etiketleri ekle
plt.title('AQI Index', fontsize=12)
plt.xlabel('Date', fontsize=12)
plt.ylabel('AQI Index', fontsize=12)

# x eksenindeki etiketleri döndür
plt.xticks(rotation=45)

# Izgara ekle
plt.grid(True)

# Grafiği göster
plt.show()

# %%
import pandas as pd

df = sample

# ReadTime sütununu datetime veri tipine dönüştürelim
#df['ReadTime'] = pd.to_datetime(df['ReadTime'])


df['Year'] = df['ReadTime'].dt.year
df['Month'] = df['ReadTime'].dt.month
df['Day'] = df['ReadTime'].dt.day

# Sonucu gösterelim
print(df)
# Out:
#                ReadTime  PM10  SO2   O3   NO2     CO  Unnamed: 6  PM10_AQI
# 0   2010-01-01 00:00:00  20.4  2.6  0.0  24.4   75.0         NaN      14.0  \
# 1   2010-01-01 01:00:00  13.2  5.4  0.0  17.8  159.5         NaN      13.0
# 2   2010-01-01 02:00:00   9.9  5.4  0.0  16.5  100.3         NaN      13.0
# 3   2010-01-01 03:00:00   3.0  6.0  0.0  21.4  119.5         NaN      13.0
# 4   2010-01-01 04:00:00   8.7  6.4  0.0  17.1  114.4         NaN      13.0
# ..                  ...   ...  ...  ...   ...    ...         ...       ...
# 995 2010-02-11 10:00:00  22.6  8.9  0.0   0.0    0.0         NaN      24.0
# 996 2010-02-11 11:00:00  24.2  9.8  0.0   0.0    0.0         NaN      23.0
# 997 2010-02-11 12:00:00  28.8  9.7  0.0   0.0    0.0         NaN      23.0
# 998 2010-02-11 13:00:00  28.6  7.6  0.0   0.0    0.0         NaN      24.0
# 999 2010-02-11 14:00:00  36.6  6.7  0.0   0.0    0.0         NaN      25.0
#
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ReadTime                  1000 non-null   datetime64[ns]
#  1   PM10                      1000 non-null   float64
#  2   SO2                       1000 non-null   float64
#  3   O3                        1000 non-null   float64
#  4   NO2                       1000 non-null   float64
#  5   CO                        1000 non-null   float64
#  6   Unnamed: 6                0 non-null      float64
#  7   PM10_AQI                  1000 non-null   float64
#  8   SO2_AQI                   1000 non-null   float64
#  9   O3_AQI                    1000 non-null   float64
#  10  NO2_AQI                   1000 non-null   float64
#  11  CO_AQI                    1000 non-null   float64
#  12  AQIINDEX_AQI              1000 non-null   float64
# ...

# %%
grouped_df = df.groupby('Year')['AQIINDEX_AQI'].mean()

# %%
# Out:
# Year
# 2010    19.486
# Name: AQIINDEX_AQI, dtype: float64
